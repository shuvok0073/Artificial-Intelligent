# %% [markdown]
# # 1. Add Two Numbers

# %%
num1 = 3
num2 = 5
sum = num1+num2
print(sum)
# Out:
# 8

# %% [markdown]
# # 2. if Statement

# %%
num = 3
if num > 0:
    print(num, "is a positive number.")
print("This is always printed.")

num = -1
if num > 0:
    print(num, "is a positive number.")
print("This is also always printed.")
# Out:
# 3 is a positive number.
# This is always printed.
# This is also always printed.

# %% [markdown]
# # 3. if and else Statement

# %%
num = 3

if num >= 0:
    print("Positive or Zero")
else:
    print("Negative number")
# Out:
# Positive or Zero

# %% [markdown]
# # 4. For loop using sum

# %%
numbers = [6, 5, 3, 8, 4, 2, 5, 4, 11]
sum = 0
for val in numbers:
	sum = sum+val
print("The sum is", sum)
# Out:
# The sum is 48

# %% [markdown]
# # 5. for loop with else

# %%
digits = [0, 1, 5]

for i in digits:
    print(i)
else:
    print("No items left.")
# Out:
# 0
# 1
# 5
# No items left.

# %% [markdown]
# # 6. Number Data Type in Python

# %%
a = 5
print(type(a))
print(type(5.0))
c = 5 + 3j
print(c + 3)
print(isinstance(c, complex))
# Out:
# <class 'int'>
# <class 'float'>
# (8+3j)
# True

# %% [markdown]
# # 7. String Operations

# %%
str1 = 'Hello'
str2 ='World!'
print('str1 + str2 = ', str1 + str2)
print('str1 * 3 =', str1 * 3)
# Out:
# str1 + str2 =  HelloWorld!
# str1 * 3 = HelloHelloHello

# %% [markdown]
# # 8. Declaring and assigning a value to a variable

# %%
website = "Apple.com"
print(website)
# Out:
# Apple.com

# %% [markdown]
# # 9. Changing value of a variable

# %%
website = "Apple.com"
website = "Programiz.com"
print(website)
# Out:
# Programiz.com

# %% [markdown]
# # 10. While Loop

# %%
n = 10
sum = 0
i = 1
while i <= n:
    sum = sum + i
    i = i+1
print("The sum is", sum)
# Out:
# The sum is 55

# %% [markdown]
# # 11. While loop with else

# %%
counter = 0

while counter < 3:
    print("Inside loop")
    counter = counter + 1
else:
    print("Inside else")
# Out:
# Inside loop
# Inside loop
# Inside loop
# Inside else

# %% [markdown]
# # 12. Converting integer to float

# %%
num_int = 123
num_flo = 1.23

num_new = num_int + num_flo

print("datatype of num_int:",type(num_int))
print("datatype of num_flo:",type(num_flo))

print("Value of num_new:",num_new)
print("datatype of num_new:",type(num_new))
# Out:
# datatype of num_int: <class 'int'>
# datatype of num_flo: <class 'float'>
# Value of num_new: 124.23
# datatype of num_new: <class 'float'>

# %% [markdown]
# # 13. List Index

# %%
my_list = ['p','r','o','b','e']

print(my_list[0])


print(my_list[2])


print(my_list[4])

n_list = ["Happy", [2,0,1,5]]


print(n_list[0][1])    


print(n_list[1][3])
# Out:
# p
# o
# e
# a
# 5

# %% [markdown]
# # 14. Negative indexing

# %%
my_list = ['p','r','o','b','e']


print(my_list[-1])


print(my_list[-5])
# Out:
# e
# p
